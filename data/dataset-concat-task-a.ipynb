# %%
import pandas as pd

# %%
# !gdown  1_Zds0QWmbn7bYn3iGrS1gyTLv33ZmwzU
# !unzip "/content/Memes-final.zip"

# %%
# AraHaMeme dataset
df1 = pd.read_excel('/content/Memes (final)/final.xlsx')
df1 = df1.drop(df1.columns[0], axis=1)
df1 = df1.drop(df1.columns[0], axis=1)

# %%
# AraMeme dataset
df2 = pd.read_csv('/content/dalia_concat.csv')
df2 = df2.drop(df2.columns[0], axis=1)
df2 = df2.drop(df2.columns[0], axis=1)

# %%
# changing columns into same name with AraHaMeme
df2.rename(columns={'image':'file_name', 'Class_image':'meme_type'}, inplace=True)

# %%
df2 = df2.iloc[:700]

# %%
df2['meme_type'] = df2['meme_type'].replace({1:'only humor'})

# %%
sns.countplot(df2.meme_type)
plt.xlabel('review score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'review score')

# %%
df1
# Out:
#         file_name    meme_type hate_type  meme_type2  hate_type2  \
# 0       img24.jpg  hate_speech       ddd         0.0         1.0
# 1       img28.jpg  hate_speech    gender         0.0         4.0
# 2       img10.jpg  hate_speech    gender         0.0         4.0
# 3        img7.jpg  hate_speech    gender         0.0         4.0
# 4       img16.jpg  hate_speech    gender         0.0         4.0
# ..            ...          ...       ...         ...         ...
# 993  img1311.jpeg  hate_speech       ddd         0.0         1.0
# 994   img1313.jpg  hate_speech       ddd         0.0         1.0
# 995   img1309.png  hate_speech       ddd         0.0         1.0
# 996   img1308.png  hate_speech       ddd         0.0         1.0
# 997   img1312.jpg  hate_speech      race         0.0         3.0
#
#                                                   text
# 0      انا نظري ضعيف ومش هخش الجيش اقسم بالله انت قناص
# 1    لما فيمينست تتابع هانتر وتعرف غون بيبحث ابوه و...
# ...

# %%
# Out:
#        file_name                                               text  \
# 0    IMG_766.jpg  يا ربى يا ساتر مين العيال الزحاليق دى ! وفين ا...
# 1    IMG_564.jpg                         تغطوا يا حريم المعرس بيدخل
# 2    IMG_768.jpg  لما حد يقولي بطل التفاهه اللى بتنزلها ع تويتر ...
# 3    IMG_829.jpg          ششششش متقولش أمك إن أنا إللي شربت اللبن !
# 4    IMG_374.jpg                              امبارح النهاردة  بكرا
# ..           ...                                                ...
# 845  IMG_228.jpg  بعد 5 دقايق كلام مع الشخص اللي كنت هتموت وتتعر...
# 846  IMG_221.jpg                 البنات ليلة الشك البنات صبحة العيد
# 847  IMG_759.jpg  لما صاحبتي تبدأ الشات بأسمي ،شكله موضوع مش بسي...
# 848  IMG_292.jpg  بعد ماكتبت تغريده طويله اعبر فيهاعن اللي داخلي...
# 849  IMG_128.jpg             نبكي بمفردنا ثم نخرج لنساند كل الباكين
#
#       meme_type Funny_image  Humor  Sarcastic  Offensive  Humor_score  \
# 0    only humor        both      1          1          0     0.666667
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(df1.meme_type)
plt.xlabel('review score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'review score')

# %%
train_df = pd.concat([df1, df2], join="outer", sort=False)
train_df
# Out:
#        file_name    meme_type hate_type  meme_type2  hate_type2  \
# 0      img24.jpg  hate_speech       ddd         0.0         1.0
# 1      img28.jpg  hate_speech    gender         0.0         4.0
# 2      img10.jpg  hate_speech    gender         0.0         4.0
# 3       img7.jpg  hate_speech    gender         0.0         4.0
# 4      img16.jpg  hate_speech    gender         0.0         4.0
# ..           ...          ...       ...         ...         ...
# 695  IMG_269.jpg   only humor       NaN         NaN         NaN
# 696  IMG_233.jpg   only humor       NaN         NaN         NaN
# 697  IMG_138.jpg   only humor       NaN         NaN         NaN
# 698  IMG_705.jpg   only humor       NaN         NaN         NaN
# 699  IMG_692.jpg   only humor       NaN         NaN         NaN
#
#                                                   text Funny_image  Humor  \
# 0      انا نظري ضعيف ومش هخش الجيش اقسم بالله انت قناص         NaN    NaN
# ...

# %%
train_df = train_df.drop(['hate_type',
'meme_type2',
'hate_type2',
'Funny_image',
'Humor',
'Sarcastic',
'Offensive',
'Humor_score',
'Sarcasm_Type',
'Target',
'Sarcastic_score',
'Offensive_score',
'Humor_Type'], axis=1)
train_df
# Out:
#        file_name    meme_type  \
# 0      img24.jpg  hate_speech
# 1      img28.jpg  hate_speech
# 2      img10.jpg  hate_speech
# 3       img7.jpg  hate_speech
# 4      img16.jpg  hate_speech
# ..           ...          ...
# 695  IMG_269.jpg   only humor
# 696  IMG_233.jpg   only humor
# 697  IMG_138.jpg   only humor
# 698  IMG_705.jpg   only humor
# 699  IMG_692.jpg   only humor
#
#                                                   text
# 0      انا نظري ضعيف ومش هخش الجيش اقسم بالله انت قناص
# 1    لما فيمينست تتابع هانتر وتعرف غون بيبحث ابوه و...
# 2                                      لا أحد النسويات
# 3    يعني لو قلعنا الحجاب وتعرينا هنطلع القمر أوماااال
# 4    فيمينيست عربية نفسي اطلع اوروبا حرية وتحرر و ح...
# ..                                                 ...
# 695  لاتوجد نساء اجمل منك مهما بحثت والله؟! يعني بح...
# 696                     أنا أخوض حرب لا أعلم عنها شيئا
# 697  لما اروح عند دكتور الاسنان يادكتور بالله عليك ...
# ...

# %%
sns.countplot(train_df.meme_type)
plt.xlabel('review score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'review score')

# %%
train_df['meme_type'].value_counts()
# Out:
# hate_speech       839
# only humor        835
# only offensive     24
# Name: meme_type, dtype: int64

# %%
train_df.to_csv('task_a.csv')
